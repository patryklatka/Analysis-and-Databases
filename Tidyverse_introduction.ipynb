# %% [markdown]
# <a href="https://colab.research.google.com/github/patryklatka/Analysis-and-Databases/blob/main/Tidyverse_introduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###In this exercise, I learned the basics of the tidyverse package. ###

# %%
install.packages("nycflights13")
install.packages("tidyverse")
library(nycflights13)
library(tidyverse)
glimpse(flights)


library(nycflights13)
library(tidyverse)
flights <- glimpse(flights)
airlines <- glimpse(airlines)
airports <- glimpse(airports)
planes <- glimpse(planes)
weather <- glimpse(weather)

# %% [markdown]
# **Had a delay of at least 2 hours.**

# %%
flights  %>% filter(dep_delay > 120 | arr_delay > 120)
# Out:
#       year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1     2013 1     1    811      630           101       1047      830
# 2     2013 1     1    848     1835           853       1001     1950
# 3     2013 1     1    957      733           144       1056      853
# 4     2013 1     1   1114      900           134       1447     1222
# 5     2013 1     1   1505     1310           115       1638     1431
# 6     2013 1     1   1525     1340           105       1831     1626
# 7     2013 1     1   1540     1338           122       2020     1825
# 8     2013 1     1   1549     1445            64       1912     1656
# 9     2013 1     1   1558     1359           119       1718     1515
# 10    2013 1     1   1732     1630            62       2028     1825
# 11    2013 1     1   1803     1620           103       2008     1750
# 12    2013 1     1   1815     1325           290       2120     1542
# ...

# %% [markdown]
# **Were flying to Huston (IAH or HOU)**

# %%
flights %>% filter(dest %in% c('IAH','HOU'))
# Out:
#      year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1    2013 1     1    517      515             2        830      819
# 2    2013 1     1    533      529             4        850      830
# 3    2013 1     1    623      627            -4        933      932
# 4    2013 1     1    728      732            -4       1041     1038
# 5    2013 1     1    739      739             0       1104     1038
# 6    2013 1     1    908      908             0       1228     1219
# 7    2013 1     1   1028     1026             2       1350     1339
# 8    2013 1     1   1044     1045            -1       1352     1351
# 9    2013 1     1   1114      900           134       1447     1222
# 10   2013 1     1   1205     1200             5       1503     1505
# 11   2013 1     1   1208     1158            10       1540     1502
# 12   2013 1     1   1248     1250            -2       1607     1607
# 13   2013 1     1   1306     1300             6       1622     1610
# ...

# %% [markdown]
# **Were from United, American, or Delta airlines**

# %%
flights %>% inner_join(airlines) %>% filter(carrier %in% c('DL', 'AA', 'U'))
# Out:
# Joining with `by = join_by(carrier)`
#       year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1     2013 1     1   542      540             2         923      850
# 2     2013 1     1   554      600            -6         812      837
# 3     2013 1     1   558      600            -2         753      745
# 4     2013 1     1   559      600            -1         941      910
# 5     2013 1     1   602      610            -8         812      820
# 6     2013 1     1   606      610            -4         858      910
# 7     2013 1     1   606      610            -4         837      845
# 8     2013 1     1   615      615             0         833      842
# 9     2013 1     1   623      610            13         920      915
# 10    2013 1     1   628      630            -2        1137     1140
# 11    2013 1     1   629      630            -1         824      810
# 12    2013 1     1   635      635             0        1028      940
# ...

# %% [markdown]
# **Flew out in the summer (July, August, September)**

# %%
flights %>% filter(month %in% c(7,8,9))
# Out:
#       year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1     2013 7     1     1      2029           212       236      2359
# 2     2013 7     1     2      2359             3       344       344
# 3     2013 7     1    29      2245           104       151         1
# 4     2013 7     1    43      2130           193       322        14
# 5     2013 7     1    44      2150           174       300       100
# 6     2013 7     1    46      2051           235       304      2358
# 7     2013 7     1    48      2001           287       308      2305
# 8     2013 7     1    58      2155           183       335        43
# 9     2013 7     1   100      2146           194       327        30
# 10    2013 7     1   100      2245           135       337       135
# 11    2013 7     1   107      2245           142       158      2359
# 12    2013 7     1   111      2359            72       448       340
# ...

# %% [markdown]
# **Have had a delay of at least two hours but no departure delay.**

# %%
flights %>% filter(dep_delay > 120 & (dep_time <= sched_dep_time) & ((sched_dep_time+(dep_delay%%60)+(dep_delay %/%60*100)) < 2360 ))
# Out:
#      year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
#      arr_delay carrier flight tailnum origin dest air_time distance hour minute
#      time_hour

# %% [markdown]
# **Had at least an hour delay but made up more than 30 minutes on the flight.**

# %%
flights %>% filter(dep_delay >= 60 & arr_delay <= -30)
# Out:
#      year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
#      arr_delay carrier flight tailnum origin dest air_time distance hour minute
#      time_hour

# %% [markdown]
# **Sort the flights to find the flights with the longest departure delay.**

# %%
flights %>% arrange(desc(dep_delay))
# Out:
#        year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1      2013  1     9   641      900           1301      1242     1530
# 2      2013  6    15  1432     1935           1137      1607     2120
# 3      2013  1    10  1121     1635           1126      1239     1810
# 4      2013  9    20  1139     1845           1014      1457     2210
# 5      2013  7    22   845     1600           1005      1044     1815
# 6      2013  4    10  1100     1900            960      1342     2211
# 7      2013  3    17  2321      810            911       135     1020
# 8      2013  6    27   959     1900            899      1236     2226
# 9      2013  7    22  2257      759            898       121     1026
# 10     2013 12     5   756     1700            896      1058     2020
# 11     2013  5     3  1133     2055            878      1250     2215
# 12     2013  1     1   848     1835            853      1001     1950
# ...

# %% [markdown]
# **Find the flights that departed earliest in the morning**

# %%
flights %>% arrange(dep_time)
# Out:
#        year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1      2013  1    13  1        2249            72       108      2357
# 2      2013  1    31  1        2100           181       124      2225
# 3      2013 11    13  1        2359             2       442       440
# 4      2013 12    16  1        2359             2       447       437
# 5      2013 12    20  1        2359             2       430       440
# 6      2013 12    26  1        2359             2       437       440
# 7      2013 12    30  1        2359             2       441       437
# 8      2013  2    11  1        2100           181       111      2225
# 9      2013  2    24  1        2245            76       121      2354
# 10     2013  3     8  1        2355             6       431       440
# 11     2013  3    18  1        2128           153       247      2355
# 12     2013  3    19  1        2250            71       120         5
# ...

# %% [markdown]
# **Sort flights to find the fastest connections.**

# %%
flights %>% arrange(air_time) %>% distinct(origin, dest, air_time)
# Out:
#       origin dest air_time
# 1     EWR    BDL  20
# 2     EWR    BDL  21
# 3     EWR    PHL  21
# 4     LGA    BOS  21
# 5     JFK    PHL  21
# 6     EWR    PHL  22
# 7     EWR    BDL  22
# 8     JFK    PHL  22
# 9     EWR    BDL  23
# 10    EWR    PHL  23
# 11    LGA    BOS  23
# 12    JFK    PHL  23
# 13    EWR    BDL  24
# 14    JFK    PHL  24
# 15    EWR    PHL  24
# 16    EWR    ALB  24
# 17    EWR    BDL  25
# 18    JFK    PHL  25
# 19    EWR    PHL  25
# 20    EWR    ALB  25
# 21    EWR    BDL  26
# 22    JFK    PHL  26
# 23    EWR    PHL  26
# 24    LGA    BOS  26
# 25    LGA    PHL  26
# 26    EWR    ALB  26
# 27    JFK    BOS  26
# 28    JFK    PHL  27
# 29    EWR    PHL  27
# 30    LGA    PHL  27
# ⋮     ⋮      ⋮    ⋮
# 11840 LGA    CAK  NA
# 11841 JFK    ROC  NA
# 11842 JFK    EGE  NA
# 11843 JFK    HOU  NA
# 11844 JFK    OAK  NA
# 11845 JFK    PHX  NA
# 11846 JFK    PSE  NA
# 11847 JFK    SJC  NA
# 11848 LGA    RSW  NA
# 11849 LGA    CRW  NA
# 11850 EWR    MYR  NA
# ...

# %% [markdown]
# **Did each day of 2013 have at least one flight?**

# %%
flights %>% filter(year==2013) %>% distinct(month, day) %>% count()
# Out:
#   n
# 1 365

# %% [markdown]
# **Which flights covered the greatest distance and which covered the shortest distance (top and bottom 10)**

# %%
flights %>% distinct(distance, origin, dest) %>% arrange(distance) %>% head(10)
# Out:
#    distance origin dest
# 1   17      EWR    LGA
# 2   80      EWR    PHL
# 3   94      JFK    PHL
# 4   96      LGA    PHL
# 5  116      EWR    BDL
# 6  143      EWR    ALB
# 7  160      EWR    PVD
# 8  169      EWR    BWI
# 9  173      JFK    MVY
# 10 184      JFK    BWI

# %%
flights %>% distinct(distance, origin, dest) %>% arrange(distance) %>% tail(10)
# Out:
#    distance origin dest
# 1  2465     JFK    BUR
# 2  2475     JFK    LAX
# 3  2521     JFK    SMF
# 4  2565     EWR    SFO
# 5  2569     JFK    SJC
# 6  2576     JFK    OAK
# 7  2586     JFK    SFO
# 8  3370     EWR    ANC
# 9  4963     EWR    HNL
# 10 4983     JFK    HNL
